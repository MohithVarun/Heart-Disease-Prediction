# %%
#Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#load dataset
data = pd.read_csv('/content/drive/MyDrive/heart.csv')

# %% [markdown]
# Attribute Information:
#
# * **age**
# * **sex**
# * **cp** : chest pain type (4 values)
#   * Value 0 : typical angina
#   * Value 1 : atypical angina
#   * Value 2 : non - anginal pain
#   * Value 3 : asymptomatic
# * **trestbps** : resting blood pressure
# * **chol** : serum cholestoral in mg/dl
# * **fbs** : fasting blood sugar > 120 mg/dl
# * **restecg** : resting electrocardiographic results (values 0,1,2)
#   * Value 0 : normal
#   * Value 1 : having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
#   * Value 2 : showing probable or definite left ventricular hypertrophy by Estes' criteria
# * **thalach** : maximum heart rate achieved
# * **exang** : exercise induced angina
# * **oldpeak** = ST depression induced by exercise relative to rest
# * **slope** : the slope of the peak exercise ST segment
#   * Value 1: upsloping
#   * Value 2: flat
#   * Value 3: downsloping
# * **ca** : number of major vessels (0-3) colored by flourosopy
# * **thal**: 0 = normal; 1 = fixed defect; 2 = reversable defect
# * **target** : 0=less chance of heart attack, 1=more chance of heart attack

# %%
#Top 5 rows
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
#Last 5 rows
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
#No : of rows & cols
# data.shape
print(f"No : of rows are {data.shape[0]}")
print(f"No : of colums are {data.shape[1]}")
# Out:
# No : of rows are 1025
# No : of colums are 14

# %%
#Information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
#Check Null values in the dataset
# data.isnull()
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#Check for duplicate data and drop them
dataDup = data.duplicated().any()
print(dataDup)
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (302, 14)

# %%
#Overall stats of our dataset
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %%
#Correlation matrix
plt.figure(figsize=(17,7))
sns.heatmap(data.corr(), annot = True)
# Out:
# <Axes: >

# %%
#Check total count of patients with & without heart disease
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(x = 'target', data=data, palette = 'deep')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
data['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
# sns.countplot(x='sex', data=data, palette='deep')
# plt.xticks([0, 1], ['Female', 'Male'])
sns.countplot(x='sex', data=data, palette='deep')
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# %%
#Gender Distrubution accoding to the target variable
sns.countplot(x='sex', hue='target', data=data)
plt.xticks([0,1],['Female', 'Male'])
plt.legend(labels=['Non-Disease', 'Disease'])
plt.show()

# %%
#Age distrubution
sns.distplot(data['age'], bins=30)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# * **cp** : chest pain type (4 values)
#   * Value 0 : typical angina
#   * Value 1 : atypical angina
#   * Value 2 : non - anginal pain
#   * Value 3 : asymptomatic

# %%
#Check Chest pain type
sns.countplot(x='cp', data = data, palette='deep')
plt.xticks([0,1,2,3], ['typical angina', "atypical angina", "non - anginal pain", "asymptomatic"])
plt.xticks(rotation=75)
plt.show()

# %%
 #Check Chest pain type according to the target
sns.countplot(x='cp', hue='target', data = data, palette='deep')
plt.xticks([0,1,2,3], ['typical angina', "atypical angina", "non - anginal pain", "asymptomatic"])
plt.xticks(rotation=75)
plt.legend(labels=['Non-Disease', 'Disease'])
plt.show()

# %%
#Show fasting blood sugar (fbs) according to the target
sns.countplot(x='fbs', hue='target', data = data)
plt.xticks([0,1], ['Female', 'Male'])
plt.legend(labels=['Non-Disease', 'Disease'])
plt.show()

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.distplot(data['trestbps'], bins=30)
plt.show()

# %%
data['trestbps'].hist()
# Out:
# <Axes: >

# %%
#Resting Bllod Pressure as per sex column
g = sns.FacetGrid(data, hue='sex', aspect=4)
g.map(sns.kdeplot, 'trestbps', shade = 'True')
plt.legend(labels=['Male', 'Female'])
plt.show()

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
#Distrubution of serum cholestrol mg/dl
data['chol'].hist()
# Out:
# <Axes: >

# %%
#Plot continuous variables

# %%
cate_val=[]
cont_val=[]

for column in data.columns:
  if data[column].nunique() <=10 :
    cate_val.append(column)
  else :
    cont_val.append(column)

# %%
cate_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
data.hist(cont_val, figsize=(15,6))
plt.tight_layout()
plt.show()
